# %%
import pandas as pd

# %%
df1=pd.read_csv("files_for_lab/csv_files/file1.csv")

# %%
df2=pd.read_csv("files_for_lab/csv_files/file2.csv",sep=",")

# %%
df3=pd.read_csv("files_for_lab/csv_files/file3.csv",sep=",")

# %%
df1.size
# Out:
# 44088

# %%
df2.size
# Out:
# 10956

# %%
df3.size
# Out:
# 77770

# %%
col1=[col_name.lower().replace(" ","_") for col_name in df1.columns]
col1[1]='state'

# %%
df1.columns=col1

# %%
col2=[col_name.lower().replace(" ","_") for col_name in df2.columns]

# %%
col2[1]="state"
col2
# Out:
# ['customer',
#  'state',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'total_claim_amount',
#  'policy_type',
#  'vehicle_class']

# %%
df2.columns=col2

# %%
col3=[col_name.lower().replace(" ","_") for col_name in df3.columns]
col3
# Out:
# ['customer',
#  'state',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %%
df3.columns=col3

# %%
df1=df1[['customer','state','gender','education','customer_lifetime_value','income','monthly_premium_auto','number_of_open_complaints','total_claim_amount','policy_type','vehicle_class']]

# %%
df3=df3[['customer','state','gender','education','customer_lifetime_value','income','monthly_premium_auto','number_of_open_complaints','total_claim_amount','policy_type','vehicle_class']]

# %%
display(df1)
display(df2)
display(df3)
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1=df1.dropna(how='all')

# %%
df2=df2.dropna(how='all')

# %%
df3=df3.dropna(how='all')

# %%
data=pd.concat([df1,df2,df3])
data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
col_type=data["customer"].dtypes.str
col_type
# Out:
# '|O'

# %%
col=data.columns
col
for c in col:
    if data[c].dtypes=="<f8":
        print (c)
# Out:
# income
# monthly_premium_auto
# total_claim_amount

# %%
col=data.columns
col
for c in col:
    if data[c].dtypes=='|O':
        print (c)
# Out:
# customer
# state
# gender
# education
# customer_lifetime_value
# number_of_open_complaints
# policy_type
# vehicle_class

# %%
data=data.drop(columns=["education","number_of_open_complaints"])

# %%
data
# Out:
#      customer       state gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto  total_claim_amount     policy_type  vehicle_class
# 0                   1000.0            2.704934   Personal Auto  Four-Door Car
# ...

# %%
data["customer_lifetime_value"].dtypes
# Out:
# dtype('O')

# %%
data=data.fillna(0)
data
# Out:
#      customer       state gender customer_lifetime_value   income  \
# 0     RB50392  Washington      0                       0      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto  total_claim_amount     policy_type  vehicle_class
# 0                   1000.0            2.704934   Personal Auto  Four-Door Car
# ...

# %%
data=data.astype({'customer_lifetime_value': 'str'})

# %%
def replace_percent(x):
    if "%" in x:
        return x.replace("%", " ")
    else:
        return x

# %%
data['customer_lifetime_value']=data['customer_lifetime_value'].apply(replace_percent)

# %%
data
# Out:
#      customer       state gender customer_lifetime_value   income  \
# 0     RB50392  Washington      0                       0      0.0
# 1     QZ44356     Arizona      F              697953.59       0.0
# 2     AI49188      Nevada      F             1288743.17   48767.0
# 3     WW63253  California      M              764586.18       0.0
# 4     GA49547  Washington      M              536307.65   36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto  total_claim_amount     policy_type  vehicle_class
# 0                   1000.0            2.704934   Personal Auto  Four-Door Car
# ...

# %%
data=data.astype({'customer_lifetime_value': 'float64'})

# %%
data
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 0     RB50392  Washington      0             0.000000e+00      0.0
# 1     QZ44356     Arizona      F             6.979536e+05      0.0
# 2     AI49188      Nevada      F             1.288743e+06  48767.0
# 3     WW63253  California      M             7.645862e+05      0.0
# 4     GA49547  Washington      M             5.363077e+05  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7067  TD14365  California      M             8.163890e+03      0.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
# 7069  Y167826  California      M             2.611837e+03      0.0
#
#       monthly_premium_auto  total_claim_amount     policy_type  vehicle_class
# 0                   1000.0            2.704934   Personal Auto  Four-Door Car
# ...

# %%
data['customer_lifetime_value'].dtype
# Out:
# dtype('float64')

# %%
data['customer_lifetime_value']=data['customer_lifetime_value'].mul(100)

# %%
data=data.drop_duplicates(keep="first")

# %%
data
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 0     RB50392  Washington      0             0.000000e+00      0.0
# 1     QZ44356     Arizona      F             6.979536e+07      0.0
# 2     AI49188      Nevada      F             1.288743e+08  48767.0
# 3     WW63253  California      M             7.645862e+07      0.0
# 4     GA49547  Washington      M             5.363076e+07  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+06  71941.0
# 7066  PK87824  California      F             3.096511e+05  21604.0
# 7067  TD14365  California      M             8.163890e+05      0.0
# 7068  UP19263  California      M             7.524442e+05  21941.0
# 7069  Y167826  California      M             2.611837e+05      0.0
#
#       monthly_premium_auto  total_claim_amount     policy_type  vehicle_class
# 0                   1000.0            2.704934   Personal Auto  Four-Door Car
# ...

# %%
data.filter(items=['income'], like<=0.0)
# Out:
#   File "C:\Users\aci\AppData\Local\Temp\ipykernel_6356\4260255255.py", line 1
#     data.filter(items=['income'], like<=0.0)
#                                            ^
# SyntaxError: positional argument follows keyword argument

# %%
filtered_data = data[data['income'] > 0]

# %%
filtered_data
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 2     AI49188      Nevada      F             1.288743e+08  48767.0
# 4     GA49547  Washington      M             5.363076e+07  36357.0
# 5     OC83172      Oregon      F             8.256298e+07  62902.0
# 6     XZ87318      Oregon      F             5.380899e+07  55350.0
# 8     DY87989      Oregon      M             2.412750e+08  14072.0
# ...       ...         ...    ...                      ...      ...
# 7063  TF56202  California      M             5.032165e+05  66367.0
# 7064  YM19146  California      F             4.100399e+05  47761.0
# 7065  LA72316  California      M             2.340599e+06  71941.0
# 7066  PK87824  California      F             3.096511e+05  21604.0
# 7068  UP19263  California      M             7.524442e+05  21941.0
#
#       monthly_premium_auto  total_claim_amount     policy_type  vehicle_class
# 2                    108.0          566.472247   Personal Auto   Two-Door Car
# ...

# %%
data.shape
# Out:
# (9134, 9)
